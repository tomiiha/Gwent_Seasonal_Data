# %%
from season_data.season_data_pull import data_finder

# %%
season_pick = 0

# %%
data_finder(season_pick)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-eb996fd0dcaf> in <module>
# ----> 1 data_finder(season_pick)
#
# ~\Dropbox\Coding\Projects\Gwent\season_data\season_data_pull.py in data_finder(pick_season)
#       5 def data_finder(pick_season):
#       6     all_files = [x for x in os.listdir() if x.endswith('.csv')]
# ----> 7     main_df = pd.read_csv(all_files[pick_season])
#       8     return main_df
#
# IndexError: list index out of range
